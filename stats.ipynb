# %%
filepath <- 'yes_no_imagined_20tests.csv'

yes_no_20 <- read.csv(file = filepath, header = FALSE, sep = ";")
boxplot(yes_no_20, main = "Ja neen classificatie", xlab= "Deelnemers", ylab= "Accuraatheid")
boxplot(yes_no_20, main = "Ja neen classificatie", xlab= "Deelnemers", ylab= "Accuraatheid", ylim= c(0,1))
# Out:
# Plot with title “Ja neen classificatie”
# Plot with title “Ja neen classificatie”
